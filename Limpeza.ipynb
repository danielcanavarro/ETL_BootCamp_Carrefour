# %%
import pandas as pd

# %%
# não esquecer de colocar o separador, se não o sistema não reconhece
# parse_date é para converter o tipo de dados de object para datetime

df = pd.read_csv("ocorrencia_2010_2020.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)

# Selecionando somente as colunas que quero manipular

df = df[['codigo_ocorrencia','codigo_ocorrencia2','ocorrencia_classificacao','ocorrencia_cidade','ocorrencia_uf','ocorrencia_aerodromo','ocorrencia_dia','ocorrencia_hora','total_recomendacoes']]

# Exibindo os 10 primeiros registros do Dataset

df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
# df.loc[linha, coluna]

df.loc[4, 'ocorrencia_cidade'] # loc é para localizar dados em um dataseet
# Out:
# 'PELOTAS'

# %%
# informa todos os dados da linha 1 até 3

df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
#
#   ocorrencia_hora  total_recomendacoes
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0

# %%
# filtrar a linha 10 e a linha 40

df.loc[[10, 40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 40              39158               39158                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10  SÃO PEDRO DO SUL            RS                 ****     2010-01-10
# 40             BELÉM            PA                 ****     2010-01-28
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 40        16:00:00                    0

# %%
df.loc[1, 'ocorrencia_classificacao']
# Out:
# 'INCIDENTE'

# %%
# filtrando todas as informações de uma coluna

df.loc[:, 'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %%
# Alterando o índice do DataFrame
# Sugestão: Selecionar uma coluna que não tenha repetições

# Verificando se a coluna é unica, ou seja, não tem repetições

df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
# Mudando o indice do DataSet para codigo_ocorrencia

df.set_index('codigo_ocorrencia', inplace = True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 ****
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# ...

# %%
# Filtrando todas as informações da ocorrencia 40211

df.loc[40211]
# Out:
# codigo_ocorrencia2                        40211
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                RIO DE JANEIRO
# ocorrencia_uf                                RJ
# ocorrencia_aerodromo                       ****
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        12:00:00
# total_recomendacoes                           0
# Name: 40211, dtype: object

# %%
# Voltando para o Índice Original

df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
# não usar isso, pois irá alterar a coluna linha toda
# Não fazer essas leseiras!

df.loc[0, 'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               40211                INCIDENTE    RIO DE JANEIRO
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          2010-01-03        12:00:00
#
#    total_recomendacoes
# 0                    0

# %%
# Não fazer essas leseiras!

df.loc[1] = 20

# %%
df.head(3)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               40211                INCIDENTE    RIO DE JANEIRO
# 1                  20                       20                20
# 2               40351                INCIDENTE    RIO DE JANEIRO
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
# 2            RJ                 SBRJ  2010-01-03 00:00:00        03:00:00
#
#    total_recomendacoes
# 0                    0
# 1                   20
# 2                    0

# %%
# Não fazer essas leseiras!

df.loc[:, 'total_recomendacoes'] = 10

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                INCIDENTE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
# Criando uma coluna de Bkp

df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                INCIDENTE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
# Alterando o campo Incidente Grave por Grave, onde a ocorrencia_uf é igual a SP

df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                    GRAVE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
# Pesquisando todas as ocorrencias onde a UF é SP

df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 11                 40069                    GRAVE         SÃO PAULO
# 16                 39809                    GRAVE         SÃO PAULO
# 18                 39828                    GRAVE            SANTOS
# 26                 39847                    GRAVE          SOROCABA
# 27                 39768                    GRAVE          CAMPINAS
# ...                  ...                      ...               ...
# 5704               79739                    GRAVE         SÃO PAULO
# 5705               79705                    GRAVE          SOROCABA
# 5715               79718                    GRAVE         SÃO PAULO
# 5742               79800                    GRAVE         SÃO PAULO
# 5747               79804                    GRAVE          CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df_AM = df.loc[df.ocorrencia_uf == 'AM']

# %%
df_AM
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 6                  40215                INCIDENTE             COARI
# 7                  39707          INCIDENTE GRAVE          CANUTAMA
# 15                 39315                 ACIDENTE          CANUTAMA
# 78                 39916          INCIDENTE GRAVE            MANAUS
# 100                40170                INCIDENTE            MANAUS
# ...                  ...                      ...               ...
# 5642               79617                INCIDENTE            LÁBREA
# 5647               79632                INCIDENTE         TABATINGA
# 5691               79709                INCIDENTE            MANAUS
# 5730               79785                INCIDENTE            MANAUS
# 5731               79746                INCIDENTE            MANAUS
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df_manaus = df.loc[df.ocorrencia_cidade == 'MANAUS']
df_manaus
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 78                 39916          INCIDENTE GRAVE            MANAUS
# 100                40170                INCIDENTE            MANAUS
# 163                40575                INCIDENTE            MANAUS
# 174                40791                INCIDENTE            MANAUS
# 184                40855                 ACIDENTE            MANAUS
# ...                  ...                      ...               ...
# 5579               79528                INCIDENTE            MANAUS
# 5606               79591                INCIDENTE            MANAUS
# 5691               79709                INCIDENTE            MANAUS
# 5730               79785                INCIDENTE            MANAUS
# 5731               79746                INCIDENTE            MANAUS
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df_manaus_aerodromo = df.loc[df.ocorrencia_aerodromo == 'SBEG']
df_manaus_aerodromo

#df.loc[df.ocorrencia_aerodromo].count_values()
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 78                 39916          INCIDENTE GRAVE            MANAUS
# 100                40170                INCIDENTE            MANAUS
# 163                40575                INCIDENTE            MANAUS
# 233                41551                INCIDENTE            MANAUS
# 500                43325                INCIDENTE            MANAUS
# 611                43812                INCIDENTE            MANAUS
# 640                44043                INCIDENTE            MANAUS
# 737                44378                INCIDENTE            MANAUS
# 754                44436                 ACIDENTE            MANAUS
# 762                44892                INCIDENTE            MANAUS
# 849                44737                INCIDENTE            MANAUS
# 881                44836                INCIDENTE            MANAUS
# 1097               45289                INCIDENTE            MANAUS
# ...

# %%
df.loc[df.ocorrencia_classificacao == 'INCIDENTE GRAVE']
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao  ocorrencia_cidade  \
# 7                  39707          INCIDENTE GRAVE           CANUTAMA
# 8                  39156          INCIDENTE GRAVE           CASCAVEL
# 9                  39711          INCIDENTE GRAVE      PARÁ DE MINAS
# 29                 39709          INCIDENTE GRAVE           CURITIBA
# 35                 39487          INCIDENTE GRAVE             PALMAS
# ...                  ...                      ...                ...
# 5741               79754          INCIDENTE GRAVE       NOVA MARINGÁ
# 5744               79753          INCIDENTE GRAVE           GOIATUBA
# 5746               79769          INCIDENTE GRAVE      MANOEL URBANO
# 5748               79757          INCIDENTE GRAVE  LAGOA DA CONFUSÃO
# 5750               79756          INCIDENTE GRAVE          VICENTINA
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df.head(10)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
# 5               39807                INCIDENTE            SALVADOR
# 6               40215                INCIDENTE               COARI
# 7               39707          INCIDENTE GRAVE            CANUTAMA
# 8               39156          INCIDENTE GRAVE            CASCAVEL
# 9               39711          INCIDENTE GRAVE       PARÁ DE MINAS
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
# ...

# %%
# Para filtrar linhas separadas, deve-se usar listas dentro de listas

df.loc[[1, 3, 5, 7, 9]]
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 1                  20                       20                  20
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 5               39807                INCIDENTE            SALVADOR
# 7               39707          INCIDENTE GRAVE            CANUTAMA
# 9               39711          INCIDENTE GRAVE       PARÁ DE MINAS
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 1            20                   20                   20              20
# 3            MT                 ****  2010-01-04 00:00:00        17:30:00
# 5            BA                 ****  2010-01-06 00:00:00        17:53:00
# 7            AM                 ****  2010-01-09 00:00:00        12:30:00
# 9            MG                 ****  2010-01-10 00:00:00        20:00:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 1                   10                20
# ...

# %%
df.loc[[0, 2, 4, 6, 8]]
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               40211                INCIDENTE    RIO DE JANEIRO
# 2               40351                INCIDENTE    RIO DE JANEIRO
# 4               40324                INCIDENTE           PELOTAS
# 6               40215                INCIDENTE             COARI
# 8               39156          INCIDENTE GRAVE          CASCAVEL
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 2            RJ                 SBRJ  2010-01-03 00:00:00        03:00:00
# 4            RS                 SBPK  2010-01-05 00:00:00        19:25:00
# 6            AM                 SBUY  2010-01-07 00:00:00        18:40:00
# 8            PR                 SBCA  2010-01-10 00:00:00        23:15:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                   10                RJ
# 2                   10                RJ
# ...

# %%
# Para Filtrar por coluna, tem que passar os nomes das colunas como lista

df.loc[:,['codigo_ocorrencia2', 'ocorrencia_classificacao', 'ocorrencia_cidade', 'ocorrencia_aerodromo']]
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                    GRAVE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_aerodromo
# 0
# 1                      20
# 2                    SBRJ
# 3                    ****
# ...

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
# 2            RJ                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3            MT                 ****  2010-01-04 00:00:00        17:30:00
# 4            RS                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                   10                RJ
# ...

# %%
# Realizando filtros nas linhas que contém ****

df.loc[df.ocorrencia_aerodromo == '****']
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 5                  39807                INCIDENTE            SALVADOR
# 7                  39707          INCIDENTE GRAVE            CANUTAMA
# 9                  39711          INCIDENTE GRAVE       PARÁ DE MINAS
# 10                 39789                INCIDENTE    SÃO PEDRO DO SUL
# ...                  ...                      ...                 ...
# 5741               79754          INCIDENTE GRAVE        NOVA MARINGÁ
# 5744               79753          INCIDENTE GRAVE            GOIATUBA
# 5745               79755                 ACIDENTE           MATO RICO
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
# Para Filtrar e modificar os valores utiliza-se a função loc
# Filtrando : df.loc[df.nome_da_coluna == 'valor_procurado']
# Substituindo valores: df.loc[df.nome_da_coluna == 'valor_procurado', ['nome_da_coluna_sem_df']] = 'novo_valor'

df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %% [raw]
# ocorrencia_aerodromo
# ****-ok-df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA
# *****-ok-df.loc[df.ocorrencia_aerodromo == '*****', ['ocorrencia_aerodromo']] = pd.NA
# ###!-ok-df.loc[df.ocorrencia_aerodromo == '###!', ['ocorrencia_aerodromo']] = pd.NA
# ####-ok-df.loc[df.ocorrencia_aerodromo == '####', ['ocorrencia_aerodromo']] = pd.NA

# %% [raw]
# # Para realizar a substituição de vários valores ao mesmo tempo utilize a função replace()
# # Sintaxe1: df.replace(valor_antigo, novo_valor, inplace=True)
# # Sintaxe2: df.replace(['lista_de_valores_que_serao_substituidos'], novo_valor, inplace=True)

# %%
df.replace(['**','****','*****','###!','####','NULL'], pd.NA, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2348
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# ocorrencia_uf_bkp              1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2348
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# ocorrencia_uf_bkp              1
# dtype: int64

# %%
# Para Preencher com valores específicos onde existem dados NA.  
# df.fillna(10, inplace=True)
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                    GRAVE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
# Para Preencher um valor especifico em uma coluna use fillna

# Exemplo: df.fillna(value={'total_recomendacoes': 10})

# %%
# Criando uma Nova Coluna

df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
# 2            RJ                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3            MT                 <NA>  2010-01-04 00:00:00        17:30:00
# 4            RS                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp  total_recomendacoes_bkp
# ...

# %%
# Excluindo uma coluna
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)

df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
# 2            RJ                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3            MT                 <NA>  2010-01-04 00:00:00        17:30:00
# 4            RS                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                   10                RJ
# ...

# %%
# Excluindo TODOS VALORES NA
# MUITO CUIDADO AO USAR ESTA FUNÇÃO, PODE PERDER TUDO!
# df.dropna()

# %%
# Para excluir linhas de uma coluna específica. use o parâmentro subset

df.dropna(subset=['ocorrencia_uf'])
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
# 2            RJ                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3            MT                 <NA>  2010-01-04 00:00:00        17:30:00
# 4            RS                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                   10                RJ
# ...

# %%
# Para Excluir valores duplicados, use drop_duplicates

df.drop_duplicates(inplace=True)
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
# 2            RJ                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3            MT                 <NA>  2010-01-04 00:00:00        17:30:00
# 4            RS                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                   10                RJ
# ...
